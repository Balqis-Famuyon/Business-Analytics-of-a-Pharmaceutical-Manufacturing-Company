# %% [markdown]
# ## Business-Analytics-of-a-Pharmaceutical-Manufacturing-Company

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
pharmacy_data = pd.read_csv("C:\Collaboration Project\Pharmacy Project\Pharm_Data.csv")
pharmacy_data.head()
# Out:
#               Distributor                         Customer Name     City  \
# 0  Gottlieb-Cruickshank                 Zieme, Doyle and Kunze    Lublin
# 1  Gottlieb-Cruickshank                              Feest PLC   Świecie
# 2  Gottlieb-Cruickshank    Medhurst-Beer Pharmaceutical Limited   Rybnik
# 3  Gottlieb-Cruickshank                   Barton Ltd Pharma Plc  Czeladź
# 4  Gottlieb-Cruickshank                    Keeling LLC Pharmacy  Olsztyn
#
#   Country  Latitude  Longitude   Channel  Sub-channel            Product Name  \
# 0  Poland   51.2333    22.5667  Hospital      Private              Topipizole
# 1  Poland   53.4167    18.4333  Pharmacy       Retail            Choriotrisin
# 2  Poland   50.0833    18.5000  Pharmacy  Institution               Acantaine
# 3  Poland   50.3333    19.0833  Hospital      Private    Lioletine Refliruvax
# 4  Poland   53.7800    20.4942  Pharmacy       Retail  Oxymotroban Fexoformin
#
# ...

# %%
pharmacy_data.sort_values('Quantity').head()
# Out:
#             Distributor                                      Customer Name  \
# 146874         Erdman                                  Gottlieb-Koss Pharm
# 186202          Koss                                       Welch-Orn Pharm
# 147048          Koss             Armstrong, Medhurst and Bogisich Pharmacy
# 221786          Koss                                             Dach PLC
# 246505  Kozey-Emmerich   Torphy, Pfeffer and Jakubowski Pharmaceutical Ltd
#
#               City  Country  Latitude  Longitude   Channel  Sub-channel  \
# 146874   Hattingen  Germany   51.3992     7.1858  Pharmacy  Institution
# 186202       Emden  Germany   53.3669     7.2061  Hospital      Private
# 147048      Lehrte  Germany   52.3725     9.9769  Hospital   Government
# 221786  Deggendorf  Germany   48.8353    12.9644  Hospital      Private
# 246505     Leipzig  Germany   51.3500    12.3833  Pharmacy       Retail
#
#              Product Name     Product Class  Quantity  Price      Sales  \
# ...

# %%
pharmacy_data['Quantity'] = np.abs(pharmacy_data['Quantity'])
pharmacy_data['Sales'] = np.abs(pharmacy_data['Sales'])

# %%
pharmacy_data.sort_values('Quantity').head()
# Out:
#            Distributor                         Customer Name      City  \
# 36453  Prohaska-Kuhic    Zemlak Group Pharmaceutical Limited  Koszalin
# 31304  Prohaska-Kuhic         Powlowski-Buckridge Pharma Plc     Ustka
# 35131  Prohaska-Kuhic                       Welch-Langworth     Warsaw
# 13988  Prohaska-Kuhic   Heidenreich Group Pharmaceutical Ltd   Rzeszów
# 24983  Prohaska-Kuhic                            Walter Ltd    Kętrzyn
#
#       Country  Latitude  Longitude   Channel  Sub-channel  \
# 36453  Poland   54.1903    16.1817  Hospital      Private
# 31304  Poland   54.5805    16.8619  Hospital      Private
# 35131  Poland   52.2167    21.0333  Pharmacy       Retail
# 13988  Poland   50.0500    22.0000  Pharmacy  Institution
# 24983  Poland   54.0833    21.3833  Pharmacy  Institution
#
#                 Product Name Product Class  Quantity  Price  Sales      Month  \
# 36453              Symbitrim    Analgesics       0.0    536    0.0    October
# ...
